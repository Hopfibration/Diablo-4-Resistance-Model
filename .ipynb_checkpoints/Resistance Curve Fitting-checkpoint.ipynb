# %% [markdown]
# Using fire resistance values gathered from diablo, we use scipy curve fitting (least squares optimization) to fit a negative exponential function to the resistance values. Calculating the MSE we get a value of 0.0174 which suggests the fitted curve is accurate to the data. Therefore our model for Diablo 4's resistance values is $r(x)=-82.639e^{-0.011(x+27.661)}+61.21$ where $x$ is the resistance value from gear and $r(x)$ is the actual resistance value reported on the character sheet. Both of these values are measured as percentages.
#
# These values were gathered from torment with a 40% resistance overcome modifier. Without this, the maximum reported resistance value is 97.8% from data, suggesting that 100% is the maximum and therefore 60% is the maximum in torment. We still model d to increase the accuracy of the fit to make resistance calculations more accurate when calculating resistance needed for damage reduction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from scipy.optimize import curve_fit

# %%
data = pd.read_csv("fireresistancenumbers.csv", header = None)

# %%
data
# Out:
#         0     1
# 0     5.1   3.1
# 1    11.1   6.5
# 2    17.1   9.7
# 3    29.1  15.7
# 4    35.1  18.4
# 5    58.1  27.9
# 6    75.0  33.3
# 7    77.7  34.2
# 8   101.0  40.2
# 9   117.9  43.6
# 10  120.6  44.1
# 11  145.6  48.2
# 12  162.5  50.1
# 13  165.2  50.5
# 14  198.2  53.6
# 15  200.8  53.9
# 16  203.4  54.1
# 17  205.9  54.3
# 18  208.2  54.5
# 19  250.7  56.8
# 20  253.8  57.0
# 21  256.7  57.2
# 22  259.5  57.3
# 23  262.1  57.5
# 24  309.1  58.6

# %%
data_inputs = data[0]
data_outputs = data[1]

# %%
#modelling as an negative exponential curve (most likely), 60% is the observed maximum possible resistance in torment
maximum_resistance=100
torment_resistance_overcome=40
def exponential_model(x,a,b,c,d):
    return a*np.exp(-b*(x-c))+d

# %%
#initial parameter values visualized from desmos
popt,pcov = curve_fit(exponential_model, data_inputs, data_outputs, p0=[-70.0, .02, -3, 60])

# %%
figure(figsize=(8, 6), dpi=80)
plt.scatter(data_inputs, data_outputs, label ="recorded data", c="r")
plt.plot(data_inputs, exponential_model(data_inputs, *popt), label="fitted curve")
plt.xlabel("Resistance Inputs")
plt.ylabel("Actual Recorded Resistance")
plt.title("Resistance Data versus Fitted Curve")
plt.legend()
plt.show()

# %%
#measuring goodness of fit using mean squared error
mse_error=np.sum((data_outputs-exponential_model(data_inputs, *popt))**2)/data.shape[0]
print(mse_error)
# Out:
# 0.017405313441368912

# %%
inputs=np.linspace(0,400,40)
figure(figsize=(8, 6), dpi=80)
plt.plot(inputs, exponential_model(inputs,*popt), label="projected resistance curve")
plt.xlabel("Resistance from Gear")
plt.xticks(np.arange(0,400,step=25))
plt.ylabel("Projected Resistance Values")
plt.title("Projected Resistance Values")
plt.legend()
plt.show()

# %%
#estimated parameter values
print("a:{:.3f}, b:{:.3f}, c:{:.3f}, d:{:.3f}".format(popt[0], popt[1], popt[2], popt[3]))
# Out:
# a:-82.639, b:0.011, c:-27.661, d:61.210

# %% [markdown]
# Next using this model we will calculate optimal resistance values on gear to avoid wasting affixes and gems. The actual damage reduction from these sources is calculated by taking the resistance value on gear and halving it, which means that 30% damage reduction is the best possible outcome from resistance. Using our estimate parameter values we define the inverse function to calculate resistance totals needed on gear to achieve character sheet damage resistances. Note this function is less accurate for high resistances.

# %%
#factor of 2 inside logarithm since damage resistance is calculated as a half of resistance value
def inverse_model_damage_resistance(x, a, b,c,d):
    return -(1/b)*np.log((2*x-d)/a)+c

# %%
#measuring goodness of fit for inverse
mse_error_inverse=np.sum((data_inputs-inverse_model_damage_resistance(.5*data_outputs, *popt))**2)/data.shape[0]
print("total mse error of inverse function:{:.2f}".format(mse_error_inverse))
mse_error_inverse_values_less_than_55=np.sum((data_inputs[:18]-inverse_model_damage_resistance(.5*data_outputs[:18], *popt))**2)/(data.shape[0]-6)
print("mse error for inverse function for resistance values less than 55% : {:.2f}".format(mse_error_inverse_values_less_than_55))
# Out:
# total mse error of inverse function:5.44
# mse error for inverse function for resistance values less than 55% : 0.27

# %%
inputs=np.linspace(0,30,60)
figure(figsize=(8, 6), dpi=80)
plt.plot(inputs, inverse_model_damage_resistance(inputs, *popt), label="Inverse Model")
damage_resistance_values=[20, 22.5, 25, 27.5, 30]
for value in damage_resistance_values:
    plt.axvline(x=value, c='r', ymax=inverse_model_damage_resistance(value, *popt)/inverse_model_damage_resistance(29.9, *popt))
    plt.axhline(y=inverse_model_damage_resistance(value,*popt), c='g', xmax=value/31)
plt.xlabel("Damage Reduction due to Resistances")
plt.ylabel("Resistances Needed on Gear")
plt.title("Damage Reduction Given by Resistances on Gear")
plt.legend(loc="lower center")
plt.show()

# %%
for value in damage_resistance_values:
    print("Damage Reduction : {:}, Resistance on Gear Needed : {:.0f}".format(value, inverse_model_damage_resistance(value, *popt)))
# Out:
# Damage Reduction : 20, Resistance on Gear Needed : 101
# Damage Reduction : 22.5, Resistance on Gear Needed : 126
# Damage Reduction : 25, Resistance on Gear Needed : 161
# Damage Reduction : 27.5, Resistance on Gear Needed : 217
# Damage Reduction : 30, Resistance on Gear Needed : 371
